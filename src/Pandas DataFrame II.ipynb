# %%
import pandas as pd

# %%
# One way to convert objects into datetime objects
df = pd.read_csv("Dataset/employees.csv")
df["Start Date"] = pd.to_datetime(df["Start Date"])
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
#df.sort_values(by="First Name", inplace=True)
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-05-25 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-05-25 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-05-25 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-05-25 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-05-25 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
# Another way to convert objects into datetime objects
df = pd.read_csv("Dataset/employees.csv",parse_dates=["Last Login Time", "Start Date"])
df.head()
Output=None
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-05-25 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-05-25 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-05-25 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-05-25 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-05-25 16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df["Team"].value_counts()
# Out:
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: Team, dtype: int64

# %%
df["Team"] = df["Team"].astype("category")

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-05-25 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-05-25 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-05-25 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-05-25 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-05-25 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df[df["Gender"] == "Male"].head(3)
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2018-05-25 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2018-05-25 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2018-05-25 13:00:00  138705    9.340
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 3               True    Finance

# %%
financeMask = df["Team"] == "Finance"

# %%
df[financeMask].head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2      Maria  Female 1993-04-23 2018-05-25 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-05-25 13:00:00  138705    9.340
# 7        NaN  Female 2015-07-20 2018-05-25 10:43:00   45906   11.598
#
#    Senior Management     Team
# 2              False  Finance
# 3               True  Finance
# 7               True  Finance

# %%
snrManagementMask = df["Senior Management"]
df[snrManagementMask].head(10)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06 2018-05-25 12:42:00   97308    6.945
# 1      Thomas    Male 1996-03-31 2018-05-25 06:53:00   61933    4.170
# 3       Jerry    Male 2005-03-04 2018-05-25 13:00:00  138705    9.340
# 4       Larry    Male 1998-01-24 2018-05-25 16:47:00  101004    1.389
# 6        Ruby  Female 1987-08-17 2018-05-25 16:20:00   65476   10.012
# 7         NaN  Female 2015-07-20 2018-05-25 10:43:00   45906   11.598
# 8      Angela  Female 2005-11-22 2018-05-25 06:29:00   95570   18.523
# 9     Frances  Female 2002-08-08 2018-05-25 06:51:00  139852    7.524
# 10     Louise  Female 1980-08-12 2018-05-25 09:01:00   63241   15.132
# 11      Julie  Female 1997-10-26 2018-05-25 15:19:00  102508   12.637
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 3                True               Finance
# ...

# %%
nonMarketingMask = df["Team"] != "Marketing"
df[nonMarketingMask].head(10)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2018-05-25 06:53:00   61933    4.170
# 2       Maria  Female 1993-04-23 2018-05-25 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2018-05-25 13:00:00  138705    9.340
# 4       Larry    Male 1998-01-24 2018-05-25 16:47:00  101004    1.389
# 5      Dennis    Male 1987-04-18 2018-05-25 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2018-05-25 16:20:00   65476   10.012
# 7         NaN  Female 2015-07-20 2018-05-25 10:43:00   45906   11.598
# 8      Angela  Female 2005-11-22 2018-05-25 06:29:00   95570   18.523
# 9     Frances  Female 2002-08-08 2018-05-25 06:51:00  139852    7.524
# 10     Louise  Female 1980-08-12 2018-05-25 09:01:00   63241   15.132
#
#     Senior Management                  Team
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# ...

# %%
salaryMask = df["Salary"] >= 100000
df[salaryMask].head(10)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2018-05-25 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2018-05-25 13:00:00  138705    9.340
# 4       Larry    Male 1998-01-24 2018-05-25 16:47:00  101004    1.389
# 5      Dennis    Male 1987-04-18 2018-05-25 01:35:00  115163   10.125
# 9     Frances  Female 2002-08-08 2018-05-25 06:51:00  139852    7.524
# 11      Julie  Female 1997-10-26 2018-05-25 15:19:00  102508   12.637
# 12    Brandon    Male 1980-12-01 2018-05-25 01:08:00  112807   17.492
# 13       Gary    Male 2008-01-27 2018-05-25 23:40:00  109831    5.831
# 17      Shawn    Male 1986-12-07 2018-05-25 19:45:00  111737    6.414
# 18      Diana  Female 1981-10-23 2018-05-25 10:27:00  132940   19.082
#
#     Senior Management                  Team
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ...

# %%
salaryCondition = df["Salary"] >= 100000
genderCondition = df["Gender"] == "Male"
teamCondition = df["Team"] == "Finance"
df[genderCondition & teamCondition & genderCondition].head()
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 3       Jerry   Male 2005-03-04 2018-05-25 13:00:00  138705    9.340
# 46      Bruce   Male 2009-11-28 2018-05-25 22:47:00  114796    6.796
# 56       Carl   Male 2006-05-03 2018-05-25 17:55:00  130276   16.084
# 68       Jose   Male 2004-10-30 2018-05-25 13:39:00   84834   14.330
# 83      Shawn   Male 2005-09-23 2018-05-25 02:55:00  148115    6.539
#
#     Senior Management     Team
# 3                True  Finance
# 46              False  Finance
# 56               True  Finance
# 68               True  Finance
# 83               True  Finance

# %%
df[salaryCondition | teamCondition & genderCondition].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2      Maria  Female 1993-04-23 2018-05-25 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-05-25 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-05-25 16:47:00  101004    1.389
# 5     Dennis    Male 1987-04-18 2018-05-25 01:35:00  115163   10.125
# 9    Frances  Female 2002-08-08 2018-05-25 06:51:00  139852    7.524
#
#    Senior Management                  Team
# 2              False               Finance
# 3               True               Finance
# 4               True       Client Services
# 5              False                 Legal
# 9               True  Business Development

# %%
mask = df["Team"].isin(["Legal", "Finance", "Engineering"])
df[mask].head(10)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2018-05-25 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2018-05-25 13:00:00  138705    9.340
# 5      Dennis    Male 1987-04-18 2018-05-25 01:35:00  115163   10.125
# 7         NaN  Female 2015-07-20 2018-05-25 10:43:00   45906   11.598
# 8      Angela  Female 2005-11-22 2018-05-25 06:29:00   95570   18.523
# 11      Julie  Female 1997-10-26 2018-05-25 15:19:00  102508   12.637
# 14   Kimberly  Female 1999-01-14 2018-05-25 07:13:00   41426   14.543
# 20       Lois     NaN 1995-04-22 2018-05-25 19:18:00   64714    4.934
# 27      Scott     NaN 1991-07-11 2018-05-25 18:58:00  122367    5.218
# 29   Benjamin    Male 2005-01-26 2018-05-25 22:06:00   79529    7.008
#
#     Senior Management         Team
# 2               False      Finance
# 3                True      Finance
# 5               False        Legal
# 7                True      Finance
# ...

# %%
nullTeamMask = df["Team"].isnull()
df[nullTeamMask].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2018-05-25 06:53:00   61933    4.170
# 10     Louise  Female 1980-08-12 2018-05-25 09:01:00   63241   15.132
# 23        NaN    Male 2012-06-14 2018-05-25 16:19:00  125792    5.042
# 32        NaN    Male 1998-08-21 2018-05-25 14:27:00  122340    6.417
# 91      James     NaN 2005-01-26 2018-05-25 23:00:00  128771    8.309
#
#     Senior Management Team
# 1                True  NaN
# 10               True  NaN
# 23               True  NaN
# 32               True  NaN
# 91              False  NaN

# %%
notNullTeamMask = df["Team"].notnull()
df[notNullTeamMask].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-05-25 12:42:00   97308    6.945
# 2      Maria  Female 1993-04-23 2018-05-25 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-05-25 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-05-25 16:47:00  101004    1.389
# 5     Dennis    Male 1987-04-18 2018-05-25 01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
df[df["Salary"].between(60000,70000)].head(10)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2018-05-25 06:53:00   61933    4.170
# 6        Ruby  Female 1987-08-17 2018-05-25 16:20:00   65476   10.012
# 10     Louise  Female 1980-08-12 2018-05-25 09:01:00   63241   15.132
# 20       Lois     NaN 1995-04-22 2018-05-25 19:18:00   64714    4.934
# 41  Christine     NaN 2015-06-28 2018-05-25 01:08:00   66582   11.308
# 47      Kathy  Female 2005-06-22 2018-05-25 04:51:00   66820    9.000
# 57      Henry    Male 1996-06-26 2018-05-25 01:44:00   64715   15.107
# 59      Irene  Female 1997-05-07 2018-05-25 09:32:00   66851   11.279
# 65      Steve    Male 2009-11-11 2018-05-25 23:44:00   61310   12.428
# 74     Thomas    Male 1995-06-04 2018-05-25 14:24:00   62096   17.029
#
#     Senior Management                  Team
# 1                True                   NaN
# 6                True               Product
# 10               True                   NaN
# ...

# %%
df[df["Bonus %"].between(5,10)].head(10)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06 2018-05-25 12:42:00   97308    6.945
# 3       Jerry    Male 2005-03-04 2018-05-25 13:00:00  138705    9.340
# 9     Frances  Female 2002-08-08 2018-05-25 06:51:00  139852    7.524
# 13       Gary    Male 2008-01-27 2018-05-25 23:40:00  109831    5.831
# 16     Jeremy    Male 2010-09-21 2018-05-25 05:56:00   90370    7.369
# 17      Shawn    Male 1986-12-07 2018-05-25 19:45:00  111737    6.414
# 23        NaN    Male 2012-06-14 2018-05-25 16:19:00  125792    5.042
# 26      Craig    Male 2000-02-27 2018-05-25 07:45:00   37598    7.757
# 27      Scott     NaN 1991-07-11 2018-05-25 18:58:00  122367    5.218
# 29   Benjamin    Male 2005-01-26 2018-05-25 22:06:00   79529    7.008
#
#     Senior Management                  Team
# 0                True             Marketing
# 3                True               Finance
# 9                True  Business Development
# ...

# %%
df[df["Start Date"].between("1990-08-21", "2000-08-21")].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06 2018-05-25 12:42:00   97308    6.945
# 1      Thomas    Male 1996-03-31 2018-05-25 06:53:00   61933    4.170
# 2       Maria  Female 1993-04-23 2018-05-25 11:17:00  130590   11.858
# 4       Larry    Male 1998-01-24 2018-05-25 16:47:00  101004    1.389
# 11      Julie  Female 1997-10-26 2018-05-25 15:19:00  102508   12.637
#
#     Senior Management             Team
# 0                True        Marketing
# 1                True              NaN
# 2               False          Finance
# 4                True  Client Services
# 11               True            Legal

# %%
mask = ~df["First Name"].duplicated(keep=False)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2018-05-25 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2018-05-25 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2018-05-25 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2018-05-25 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2018-05-25 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2018-05-25 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2018-05-25 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2018-05-25 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2018-05-25 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %%
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-05-25 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2018-05-25 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2018-05-25 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2018-05-25 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2018-05-25 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
len(df)
# Out:
# 1000

# %%
df.drop_duplicates(subset=["First Name", "Team"]).head(10)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-05-25 10:20:00   61602   11.849
# 440      Aaron   Male 1990-07-22 2018-05-25 14:53:00   52119   11.343
# 137       Adam   Male 2011-05-21 2018-05-25 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2018-05-25 20:57:00  110194   14.727
# 302       Adam   Male 2007-07-05 2018-05-25 11:59:00   71276    5.027
# 300       Alan   Male 1988-06-26 2018-05-25 03:54:00  111786    3.592
# 53        Alan    NaN 2014-03-03 2018-05-25 13:28:00   40341   17.578
# 610       Alan   Male 2012-02-17 2018-05-25 00:26:00   41453   10.084
# 372     Albert   Male 1997-02-01 2018-05-25 16:20:00   67827   19.717
# 458     Albert   Male 2007-09-30 2018-05-25 17:34:00  102626   15.843
#
#      Senior Management             Team
# 101               True        Marketing
# 440               True  Client Services
# 137              False     Distribution
# ...

# %%
df["Gender"].unique()
# Out:
# [Male, Female, NaN]
# Categories (2, object): [Male, Female]

# %%
df["Gender"].nunique()
# Out:
# 2

# %%
df["Team"].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
df["Team"].nunique(dropna=False)
# Out:
# 11
